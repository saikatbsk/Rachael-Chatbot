# %% [markdown]
# ## Explore the Ubuntu Dialog Corpus Dataset
#
# The Ubuntu Dialog Corpus (UDC) ([paper](https://arxiv.org/abs/1506.08909), [github](https://github.com/rkadlec/ubuntu-ranking-dataset-creator)) is one of the largest public dialog datasets available. It’s based on chat logs from the Ubuntu channels on a public IRC network.
#
# Use this link to download the data files:
# [![link](http://saikatbasak.in/public/img/link.gif "Link")](https://drive.google.com/open?id=0B_bZck-ksdkpVEtVc1R6Y01HMWM)

# %%
""" Importing our dependencies. """
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import random

plt.style.use('ggplot')
# %matplotlib inline

# %%
""" Loading a subset of the dataset. """
nb_records = 1000000 # Number of records in file
nb_samples = 100000  # Desired sample size
skip = sorted(random.sample(range(1, nb_records+1), nb_records-nb_samples))

train_df = pd.read_csv('../data/train.csv', skiprows=skip)
train_df.Label = train_df.Label.astype('category')

test_df = pd.read_csv('../data/test.csv', skiprows=skip)
validation_df = pd.read_csv('../data/valid.csv', skiprows=skip)

# %%
train_df.describe()
# Out:
#                                                   Context      Utterance  \
# count                                              100000         100000
# unique                                              99574          89323
# top     realiz that no servic = secur be just not true...  thank __eou__
# freq                                                    2           1234
#
#          Label
# count   100000
# unique       2
# top          0
# freq     50150

# %%
train_df.Label.hist()
plt.title('Training Label Distribution')
plt.show()

# %%
pd.options.display.max_colwidth = 500
train_df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Context  \
# ...

# %%
fig = plt.figure()
g = gridspec.GridSpec(1, 2, right=1.5, wspace=0.5)

train_df_context_len = train_df.Context.str.split(' ').apply(len)
fig.add_subplot(g[0])
plt.title("Training Context Length Statistics")
train_df_context_len.hist()

train_df_utterance_len = train_df.Utterance.str.split(' ').apply(len)
fig.add_subplot(g[1])
plt.title("Training Utterance Length Statistics")
train_df_utterance_len.hist()

plt.show()

# %%
pd.options.display.max_colwidth = 500
test_df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Context  \
# ...

# %%
test_df.describe()
# Out:
#                                                                                                                                                                                                                                    Context  \
# count                                                                                                                                                                                                                                 1889
# unique                                                                                                                                                                                                                                1889
# top     be it possibl to find out what architectur an instal applic be build for ? i 'm not sure if my ide be intel86 or amd64 __eou__ i take it that it be 64 bite ? __eou__ __eot__ yes , that what it say __eou__ 1.6 ? __eou__ __eot__
# ...
